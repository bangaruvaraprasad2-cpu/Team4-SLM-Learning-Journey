# %% [markdown]
# 1 Create a Multiplication Table Generator using Functions

# %%
def multiplication_table(number):
    for i in range(1, 11):
        print(f"{number} x {i} = {number * i}")

num = int(input("Enter a number: "))
multiplication_table(num)
# Out:
# Enter a number: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %% [markdown]
# 2 Create a Simple Data Store using Lists

# %%
data_store = []

data_store.append("shiva")
data_store.append("sai")
data_store.append("prasad")

print("Stored Data:")
print(data_store)
# Out:
# Stored Data:
# ['shiva', 'sai', 'prasad']

# %% [markdown]
# 3 Add Student Names into a List
#
# > Add blockquote

# %%
students = []

n = int(input("Enter number of students:"))
for i in range(n):
    name=input("Enter student name:")
    students.append(name)
print("Student name:")
for name in students:
    print(name)
# Out:
# Enter number of students:1
# Enter student name:virat
# Student name:
# virat

# %% [markdown]
# 4 Display all Student Names using a Loop

# %%
students = ["Rahul", "varan", "Kiran"]

print("Student List:")
for student in students:
    print(student)
# Out:
# Student List:
# Rahul
# varan
# Kiran

# %% [markdown]
# 5 Create a Function to Add Numbers

# %%
def add_numbers(a, b):
    return a + b

result = add_numbers(10, 20)
print("Sum =", result)
# Out:
# Sum = 30

# %% [markdown]
# 6 Create a Function to Display Student Details

# %%
def display_student(name, age, course):
    print("Student Details")
    print("Name :", name)
    print("Age :", age)
    print("Course :", course)

display_student("Rahul", 20, "Python")
# Out:
# Student Details
# Name : Rahul
# Age : 20
# Course : Python
